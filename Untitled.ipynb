# %%
import pandas as pd
import numpy as np
headers = ["Artist", "Album", "Song", "DateTime"]
lastfm = pd.read_csv('umarsabir.csv', names = headers, parse_dates=[3])

# %%
def get_season(row):
    if row['Date'].month >= 3 and row['Date'].month <= 5:
        return 'Spring'
    elif row['Date'].month >= 6 and row['Date'].month <= 8:
        return 'Summer'
    elif row['Date'].month >= 9 and row['Date'].month <= 11:
        return 'Fall'
    else:
        return 'Winter'
    
def ampm(row):
    if row["DateTime"].hour < 12:
        return 'AM'
    else:
        return 'PM'

# %%
temp = pd.DatetimeIndex(lastfm['DateTime'])
lastfm['DateTime'] = pd.DatetimeIndex(lastfm['DateTime'])
lastfm['Date'] = temp.date
lastfm['Time'] = temp.time

# %%
lastfm['Date'] = pd.to_datetime(lastfm['Date'])
DotW = lastfm['Date'].dt.weekday_name
lastfm['Day of the Week'] = DotW
lastfm['Season'] = lastfm.apply(get_season, axis=1)
lastfm["TOD"] = lastfm.apply(ampm, axis=1)
lastfm = lastfm.dropna()
lastfm = lastfm[lastfm.Date.dt.year >= 2012]

# %%
lastfm
# Out:
#                                      Artist                          Album  \
# 0                             Ariana Grande                   Thank U Next
# 1                               Swizz Beatz                         POISON
# 2      Curren$y Freddie Gibbs The Alchemist                          Fetti
# 3      Curren$y Freddie Gibbs The Alchemist                          Fetti
# 4      Curren$y Freddie Gibbs The Alchemist                          Fetti
# 5      Curren$y Freddie Gibbs The Alchemist                          Fetti
# 6      Curren$y Freddie Gibbs The Alchemist                          Fetti
# 7      Curren$y Freddie Gibbs The Alchemist                          Fetti
# 8      Curren$y Freddie Gibbs The Alchemist                          Fetti
# 9      Curren$y Freddie Gibbs The Alchemist                          Fetti
# 10     Curren$y Freddie Gibbs The Alchemist                          Fetti
# 11     Curren$y Freddie Gibbs The Alchemist                          Fetti
# 12     Curren$y Freddie Gibbs The Alchemist                          Fetti
# 13     Curren$y Freddie Gibbs The Alchemist                          Fetti
# 14     Curren$y Freddie Gibbs The Alchemist                          Fetti
# 15     Curren$y Freddie Gibbs The Alchemist                          Fetti
# 16     Curren$y Freddie Gibbs The Alchemist                          Fetti
# 17     Curren$y Freddie Gibbs The Alchemist                          Fetti
# 18     Curren$y Freddie Gibbs The Alchemist                          Fetti
# 19     Curren$y Freddie Gibbs The Alchemist                          Fetti
# 20     Curren$y Freddie Gibbs The Alchemist                          Fetti
# 21     Curren$y Freddie Gibbs The Alchemist                          Fetti
# 22     Curren$y Freddie Gibbs The Alchemist                          Fetti
# 23     Curren$y Freddie Gibbs The Alchemist                          Fetti
# 24     Curren$y Freddie Gibbs The Alchemist                          Fetti
# 25     Curren$y Freddie Gibbs The Alchemist                          Fetti
# 26     Curren$y Freddie Gibbs The Alchemist                          Fetti
# 27     Curren$y Freddie Gibbs The Alchemist                          Fetti
# 28     Curren$y Freddie Gibbs The Alchemist                          Fetti
# 29        The Roots Peedi Peedi Truck North                 How I Got Over
# ...                                     ...                            ...
# 69360                               OutKast                      Stankonia
# 69361                               OutKast                      Stankonia
# 69362                               OutKast                      Stankonia
# 69363                               OutKast                      Stankonia
# 69364                               OutKast                      Stankonia
# 69365                               OutKast                      Stankonia
# 69366                               OutKast                      Stankonia
# 69367                               OutKast                      Stankonia
# 69368                                 Jay-Z                The Black Album
# 69369                                 Jay-Z                The Black Album
# 69370                                 Jay-Z                The Black Album
# 69371                                 Jay-Z                The Black Album
# 69372                                 Jay-Z                The Black Album
# 69373                       CunninLynguists                     Oneirology
# 69374                       CunninLynguists                     Oneirology
# 69375                       CunninLynguists                     Oneirology
# 69376                       CunninLynguists                     Oneirology
# 69377                       CunninLynguists                     Oneirology
# 69378                       CunninLynguists                     Oneirology
# 69379                       CunninLynguists                     Oneirology
# 69380                       CunninLynguists                     Oneirology
# 69381                            Classified  Handshakes And Middle Fingers
# 69382                            Classified  Handshakes And Middle Fingers
# 69383                            Classified  Handshakes And Middle Fingers
# 69384                  Army of the Pharaohs              The Unholy Terror
# 69363 2012-01-21  23:37:00        Saturday  Winter  PM
# 69364 2012-01-21  23:29:00        Saturday  Winter  PM
# 69365 2012-01-21  22:42:00        Saturday  Winter  PM
# 69366 2012-01-21  21:58:00        Saturday  Winter  PM
# 69367 2012-01-21  21:56:00        Saturday  Winter  PM
# 69368 2012-01-19  05:00:00        Thursday  Winter  AM
# 69369 2012-01-19  04:56:00        Thursday  Winter  AM
# 69370 2012-01-19  04:51:00        Thursday  Winter  AM
# 69371 2012-01-19  04:47:00        Thursday  Winter  AM
# 69372 2012-01-19  04:45:00        Thursday  Winter  AM
# 69373 2012-01-19  00:33:00        Thursday  Winter  AM
# 69374 2012-01-19  00:28:00        Thursday  Winter  AM
# 69375 2012-01-19  00:26:00        Thursday  Winter  AM
# 69376 2012-01-19  00:23:00        Thursday  Winter  AM
# 69377 2012-01-19  00:18:00        Thursday  Winter  AM
# 69378 2012-01-19  00:03:00        Thursday  Winter  AM
# 69379 2012-01-18  23:59:00       Wednesday  Winter  PM
# 69380 2012-01-18  23:54:00       Wednesday  Winter  PM
# 69381 2012-01-15  02:58:00          Sunday  Winter  AM
# 69382 2012-01-15  02:54:00          Sunday  Winter  AM
# 69383 2012-01-15  02:50:00          Sunday  Winter  AM
# 69384 2012-01-01  01:00:00          Sunday  Winter  AM
# 69385 2012-01-01  00:55:00          Sunday  Winter  AM
# 69386 2012-01-01  00:51:00          Sunday  Winter  AM
# 69387 2012-01-01  00:48:00          Sunday  Winter  AM
# 69388 2012-01-01  00:44:00          Sunday  Winter  AM
# 69389 2012-01-01  00:40:00          Sunday  Winter  AM
#
# [68915 rows x 9 columns]

# %%
import matplotlib.pyplot as plt
time1 = lastfm['Date'].dt.month
time2 = lastfm['Date'].dt.date
time3 = lastfm['Date'].dt.year


timemonth = pd.DataFrame(time1.value_counts())
timedate = pd.DataFrame(time2.value_counts())
timeyear = pd.DataFrame(time3.value_counts())
Season = pd.DataFrame(lastfm['Season'].value_counts())
DoftheW = pd.DataFrame(lastfm['Day of the Week'].value_counts())

# Get current size
fig_size = plt.rcParams["figure.figsize"]
 
# Prints: [8.0, 6.0]
# Set figure width to 12 and height to 9
fig_size[0] = 18
fig_size[1] = 15
plt.rcParams["figure.figsize"] = fig_size

timemonth.sort_index(inplace=True)
timedate.sort_index(inplace=True)
timeyear.sort_index(inplace=True)
Season.sort_index(inplace=True)
DoftheW.sort_index(inplace=True)

fig = plt.figure()

ax1 = fig.add_subplot(231)
ax1.bar(timedate.index, timedate.Date)
ax1.xaxis_date()

ax2 = fig.add_subplot(232)
ax2.bar(timeyear.index, timeyear.Date)

ax3 = fig.add_subplot(233)
ax3.bar(timemonth.index, timemonth.Date)


ax4 = fig.add_subplot(234)
idx=Season.index.tolist()
x = range(len(idx))
plt.bar(x, Season['Season'].values)
plt.xticks(x, idx, rotation=90)


ax5 = fig.add_subplot(235)
idy=DoftheW.index.tolist()
y = range(len(idy))
plt.bar(y, DoftheW['Day of the Week'].values)
plt.xticks(y, idy, rotation=90)

fig.show()


# del timemonth, timeyear, timedate, Season, DoftheW

# %%
fig = plt.figure()
ax1 = fig.add_subplot(221)
TOD = pd.DataFrame(lastfm['TOD'].value_counts())
idx=TOD.index.tolist()
x = range(len(idx))
plt.bar(x, TOD['TOD'].values)
plt.xticks(x, idx)

specificTime = pd.DataFrame(lastfm['DateTime'].dt.hour.value_counts())
ax2 = fig.add_subplot(222)
plt.bar(specificTime.index, specificTime.DateTime.values)
# Out:
# <Container object of 24 artists>

# %%
am = lastfm[lastfm['TOD'] == 'AM']
pm = lastfm[lastfm['TOD'] == 'PM']

amVC = pd.DataFrame(am['Day of the Week'].value_counts())
pmVC = pd.DataFrame(pm['Day of the Week'].value_counts())

ammonthlyVC = pd.DataFrame(am['Date'].dt.month.value_counts())
pmmonthlyVC = pd.DataFrame(pm['Date'].dt.month.value_counts())

amyearlyVC = pd.DataFrame(am['Date'].dt.year.value_counts())
pmyearlyVC = pd.DataFrame(pm['Date'].dt.year.value_counts())

amSeasonVC = pd.DataFrame(am['Season'].value_counts())
pmSeasonVC = pd.DataFrame(pm['Season'].value_counts())

fig = plt.figure()

ax1 = fig.add_subplot(221)
idy=DoftheW.index.tolist()
y = range(len(idy))
plt.bar(y, amVC['Day of the Week'].values, color='b',align='center')
plt.bar(y, pmVC['Day of the Week'].values, color='g',align='center')
plt.xticks(y, idy, rotation=90)
ax1.legend( ('AM', 'PM') )

ax2 = fig.add_subplot(222)
idy=Season.index.tolist()
y = range(len(idy))
plt.bar(y, amSeasonVC['Season'].values, color='b',align='center')
plt.bar(y, pmSeasonVC['Season'].values, color='g',align='center')
plt.xticks(y, idy, rotation=90)
ax2.legend( ('AM', 'PM') )


ax2 = fig.add_subplot(223)
idy=timemonth.index.tolist()
y = range(len(idy))
plt.bar(y, ammonthlyVC['Date'].values, color='b',align='center')
plt.bar(y, pmmonthlyVC['Date'].values, color='g',align='center')
plt.xticks(y, idy)
ax2.legend( ('AM', 'PM') )


ax2 = fig.add_subplot(224)
idy=timeyear.index.tolist()
y = range(len(idy))
plt.bar(y, amyearlyVC['Date'].values, color='b',align='center')
plt.bar(y, pmyearlyVC['Date'].values, color='g',align='center')
plt.xticks(y, idy)
ax2.legend( ('AM', 'PM') )

# %%
# pd.pivot_table(lastfm,index=["Day of the Week"],values=["Date"],aggfunc=len)
lastfm['Month'] = lastfm['Date'].dt.month
lastfm['Year'] = lastfm['Date'].dt.year
dotw = pd.pivot_table(lastfm,index=[ "Year"],values=["TOD"],columns=["Day of the Week"],aggfunc=len)
dotw
# Out:
#                    TOD
# Day of the Week Friday Monday Saturday Sunday Thursday Tuesday Wednesday
# Year
# 2012              1053    965     1497   1145     1360     869      1179
# 2013              1614   1184     1527   1494     1562    1177      1210
# 2014              1060   1276     1241   1098     1453    1232      1167
# 2015              1878   1992     1132   1003     1660    1606      1927
# 2016              2132   1864     1027   1254     1990    2431      1559
# 2017              2010   1633      877    936     1533    1355      1904
# 2018              1794   1398      835    590     1453    1292      1487
